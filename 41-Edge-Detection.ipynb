# %% [markdown]
# # Canny Edge Detection
# https://en.wikipedia.org/wiki/Canny_edge_detector

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/computer vision/DATA/dog-with-kid.jpg')

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img, threshold1=200, threshold2=127)

# %%
plt.imshow(edges)

# %%
edges = cv2.Canny(image=img, threshold1=0, threshold2=255)

# %%
plt.imshow(edges)

# %% [markdown]
# # blur

# %%
blurred_image = cv2.blur(img,ksize=(5,5))

# %%
plt.imshow(blurred_image)

# %%
edges = cv2.Canny(image=blurred_image, threshold1=0, threshold2=255)

# %%
plt.imshow(edges)
