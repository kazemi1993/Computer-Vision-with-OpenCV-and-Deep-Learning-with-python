# %% [markdown]
# # Gradients

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/computer vision/DATA/periodictable.png',0)

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
display_img(img)

# %%
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
display_img(sobelx)

# %%
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
display_img(sobely)

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F)
display_img(laplacian)

# %% [markdown]
# ## Combining Previous Ideas
#
# Let's play around with these images with some of the other ideas we've already seen!

# %% [markdown]
# ### Blending Images

# %%
blended = cv2.addWeighted(src1=sobelx,alpha=0.5,src2=sobely,beta=0.5,gamma=0)

# %%
display_img(blended)

# %% [markdown]
# ### Thresholds

# %%
ret,th1 = cv2.threshold(blended,140,255,cv2.THRESH_BINARY_INV)
display_img(th1)

# %%
ret,th1 = cv2.threshold(img,160,255,cv2.THRESH_BINARY)
display_img(th1)

# %% [markdown]
# ##### Great Work! Keep this sudoku in mind. Later on you will have the computer vision skills to create a program that can solve sudoku puzzles just by reading the image!
