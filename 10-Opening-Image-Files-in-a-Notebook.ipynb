# %% [markdown]
# # Opening Image Files in a Notebook

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kazem\anaconda3\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kazem\anaconda3\lib\site-packages (from opencv-python) (1.20.1)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### WARNING! Make sure to provide the correct path like we do in our notebooks! ALWAYS confirm that your file path is correct before posting a question on this.

# %%
# WONT GIVE ERROR! GIVES NONE INSTEAD!!!
img = cv2.imread("somepath/nopictureexist.jpg")

# %%
print(img)
# Out:
# None

# %%
img = cv2.imread('../DATA/ai.jpg')

# %%
img
# Out:
# array([[[57, 66, 80],
#         [60, 69, 83],
#         [58, 67, 81],
#         ...,
#         [48, 71, 87],
#         [38, 63, 79],
#         [33, 58, 74]],
#
#        [[60, 69, 83],
#         [63, 72, 86],
#         [61, 70, 84],
#         ...,
#         [47, 72, 88],
#         [39, 64, 80],
#         [35, 60, 76]],
#
#        [[62, 71, 85],
#         [65, 74, 88],
#         [63, 72, 86],
#         ...,
#         [49, 75, 89],
#         [43, 68, 84],
#         [39, 64, 80]],
#
#        ...,
#
#        [[13, 33, 44],
#         [13, 33, 44],
#         [13, 33, 44],
#         ...,
#         [ 1, 32, 55],
#         [ 1, 32, 55],
#         [ 1, 32, 55]],
#
#        [[13, 33, 44],
#         [13, 33, 44],
#         [13, 33, 44],
#         ...,
#         [ 1, 32, 55],
#         [ 1, 32, 55],
#         [ 1, 32, 55]],
#
#        [[13, 33, 44],
#         [13, 33, 44],
#         [13, 33, 44],
#         ...,
#         [ 1, 32, 55],
#         [ 1, 32, 55],
#         [ 1, 32, 55]]], dtype=uint8)

# %% [markdown]
# ------------

# %%
img_bgr = cv2.imread('../DATA/ai.jpg')
plt.imshow(img_bgr)

# %% [markdown]
# The image has been correctly loaded by openCV as a numpy array, but the color of each pixel has been sorted as BGR.
# Matplotlib's plot expects an RGB image so, for a correct display of the image, it is necessary to swap those channels.
# This operation can be done either by using openCV conversion functions cv2.cvtColor() or by working directly with the numpy array.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread('../DATA/ai.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv2.imread('../DATA/ai.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %% [markdown]
# ## Resize Images

# %%
img_rgb.shape
# width, height, color channels
# Out:
# (1000, 1500, 3)

# %%
img =cv2.resize(img_rgb,(1300,275))

# %%
plt.imshow(img)

# %% [markdown]
# ### By ratio

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %% [markdown]
# ### Flipping Images

# %%
# Along central x axis
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)

# %%
# Along central y axis
new_img = cv2.flip(new_img,1)
plt.imshow(new_img)

# %%
# Along both axis
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img)

# %% [markdown]
# --------

# %% [markdown]
# # Saving Image Files

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('my_new_picture.jpg',new_img)
# Out:
# True

# %% [markdown]
# Keep in mind, the above stored the BGR version of the image.

# %% [markdown]
# ## Larger Displays in the Notebook

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)
